# %%
from neo4j import GraphDatabase

# %% [markdown]
# ### Neo4j Manual
#
# 1/To create a new node (each note is a distinct unique observation, cannot contain multiple records):
# ```cypher
# CREATE (t:table {col1: 'value1',
#                 col2: 'value2',
#                 col3: 'value3'}) -> the t is the alias of the table name
# ```
# These columns will be accessed via the t.col
#
# 2/To match relationship between nodes
# ```cypher
# MATCH (t2: table2 {id: '......'}),
#         (t3: table3 {id: '......'})
# MERGE(t2)-[:RELATIONSHIP]->(t3); -> define the relationship and the arrow distance
# RETURN t2, t3;
# ```
# or
# ```cypher
# MATCH (t2: table2 {id: '......'}),
#         (t3: table3 {id: '......'})
# MERGE(cl)-[:HAS/INTERACTION {roles: 'interactions'}]->(a2) for more specific interaction
# RETURN t2, t3;
# ```
# 3/Insert data into a node
# ```cypher
# MATCH (t:table {id:'123'})
# SET t.col1 = 'value1'
#     t.col2 = 'value2'
#     t.col3 = 'value3'
# RETURN t
# ```
# 4/Create a node/ relationship if it doesn't exist, or match if it does
# ```cypher
# MERGE (t:table {id: '123'})
# RETURN t
# ```
# 5/Check for existing relationship
# ```cypher
# MATCH (t:table1),
#         (t2:table2)
# EXISTS((t)-[:RELATES/WITH]->(t2))
# ```
# 6/Delete
# ```cypher
# DELETE n
# ```
# or
# ```cypher
# MATCH (n)
# DETACH DELETE n;
# ```
# to delete all
#
#
# 7/Query
# ```cypher
# MATCH (t:table1) WHERE t.col1 = '....'
# ORDER BY t.col1 DESC
# RETURN t as table1
# ```
# 8/Query the Viz
#
# //Show all nodes and relationship
# ```cypher
# MATCH (n)-[r]->(m)
# RETURN n, r, m;
# ```
# // Show all nodes but relationship
# ```cypher
# MATCH (n)
# RETURN n;
# ```
# // Show Schema (Labels + relation type)
# ```cypher
# CALL db.schema.visualization();
# ```
# // Sample down return
# ```cypher
# MATCH (n)-[r]->(m)
# RETURN n, r, m
# LIMIT 200; //limit to 200 nodes
# ```

# %%
import os

URI = os.getenv('NEO4J_URI')
AUTH = ("neo4j", os.getenv('NEO4J_AUTH'))

# %%
def query_neo4j(query: str, **params):
    """
    Function to query the Neo4j db, used for Query and retrieving data
    """
    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        driver.verify_connectivity()
        records, summary, keys = driver.execute_query(
            query,
            **params,  #Expect params to be in dictionary format
            database="neo4j"
        )
        return [record.data() for record in records]

def dml_ddl_neo4j(query: str, **params):
    """
    Function for DDL and DML in Neo4j database
    """    
    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        driver.verify_connectivity()
        records, summary, keys = driver.execute_query(
            query,
            **params,   #Expect params to be in dictionary format
            database="neo4j"
        )

        print("Created {nodes_created} nodes, {rels_created} rels in {time} ms.".format(
            nodes_created=summary.counters.nodes_created,
            rels_created=summary.counters.relationships_created,
            time=summary.result_available_after
        ))

# %%
'''
Run this in .cypher file after connecting env to Neo4j and open query results tab in terminal to see the result

MATCH (n: Test_3)-[r]->(m: Test_3) RETURN n, r, m
'''

#Don't do this for querying, only do it for DDL/DML operations

query_neo4j('MATCH (n)-[r]->(m) RETURN n, r, m')
# Out:
# ---------------------------------------------------------------------------
# ServiceUnavailable                        Traceback (most recent call last)
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\io\_bolt_socket.py:328, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     327 try:
# --> 328     s = cls._connect_secure(
#     329         resolved_address, tcp_timeout, keep_alive, ssl_context
#     330     )
#     331     agreed_version, handshake, response = s._handshake(
#     332         resolved_address, deadline
#     333     )
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:415, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, keep_alive, ssl_context)
#     414     log.debug("[#0000]  S: <TIMEOUT> %s", resolved_address)
# --> 415     raise ServiceUnavailable(
#     416         "Timed out trying to establish connection to "
#     417         f"{resolved_address!r}"
#     418     ) from None
#     419 except Exception as error:
#
# ServiceUnavailable: Timed out trying to establish connection to ResolvedIPv4Address(('52.207.236.148', 7687))
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[4], line 9
#       1 '''
#       2 Run this in .cypher file after connecting env to Neo4j and open query results tab in terminal to see the result
#       3
#       4 MATCH (n: Test_3)-[r]->(m: Test_3) RETURN n, r, m
#       5 '''
#       7 #Don't do this for querying, only do it for DDL/DML operations
# ----> 9 query_neo4j('MATCH (n)-[r]->(m) RETURN n, r, m')
#
# Cell In[3], line 6, in query_neo4j(query, **params)
#       2 """
#       3 Function to query the Neo4j db, used for Query and retrieving data
#       4 """
#       5 with GraphDatabase.driver(URI, auth=AUTH) as driver:
# ----> 6     driver.verify_connectivity()
#       7     records, summary, keys = driver.execute_query(
#       8         query,
#       9         **params,  #Expect params to be in dictionary format
#      10         database="neo4j"
#      11     )
#      12     return [record.data() for record in records]
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\driver.py:1090, in Driver.verify_connectivity(self, **config)
#    1083     experimental_warn(
#    1084         "All configuration key-word arguments to "
#    1085         "verify_connectivity() are experimental. They might be "
#    1086         "changed or removed in any future version without prior "
#    1087         "notice."
#    1088     )
#    1089 session_config = self._read_session_config(config)
# -> 1090 self._get_server_info(session_config)
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\driver.py:1305, in Driver._get_server_info(self, session_config)
#    1303 def _get_server_info(self, session_config) -> ServerInfo:
#    1304     with self._session(session_config) as session:
# -> 1305         return session._get_server_info()
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\work\session.py:183, in Session._get_server_info(self)
#     181 def _get_server_info(self):
#     182     assert not self._connection
# --> 183     self._connect(
#     184         READ_ACCESS, liveness_check_timeout=0, unprepared=True
#     185     )
#     186     server_info = self._connection.server_info
#     187     self._disconnect()
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\work\session.py:136, in Session._connect(self, access_mode, **acquire_kwargs)
#     134     access_mode = self._config.default_access_mode
#     135 try:
# --> 136     super()._connect(
#     137         access_mode, auth=self._config.auth, **acquire_kwargs
#     138     )
#     139 except asyncio.CancelledError:
#     140     self._handle_cancellation(message="_connect")
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\work\workspace.py:199, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     189 acquire_kwargs_ = {
#     190     "access_mode": access_mode,
#     191     "timeout": acquisition_timeout,
#    (...)    196     "database_callback": self._make_db_resolution_callback(),
#     197 }
#     198 acquire_kwargs_.update(acquire_kwargs)
# --> 199 self._connection = self._pool.acquire(**acquire_kwargs_)
#     200 if (
#     201     target_db.guessed
#     202     and not self._pinned_database
#    (...)    206     # support SSR.
#     207     # => we need to fall back to explicit home database resolution
#     208     log.debug(
#     209         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     210         "falling back to explicit home database resolution",
#     211     )
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\io\_pool.py:676, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     669 log.debug(
#     670     "[#0000]  _: <POOL> acquire direct connection, "
#     671     "access_mode=%r, database=%r",
#     672     access_mode,
#     673     database,
#     674 )
#     675 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 676 return self._acquire(
#     677     self.address, auth, deadline, liveness_check_timeout, unprepared
#     678 )
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\io\_pool.py:417, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     412             raise ClientError(
#     413                 "failed to obtain a connection from the pool within "
#     414                 f"{deadline.original_timeout!r}s (timeout)"
#     415             )
#     416 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 417 return connection_creator()
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\io\_pool.py:230, in IOPool._acquire_new_later.<locals>.connection_creator()
#     228 try:
#     229     try:
# --> 230         connection = self.opener(
#     231             address, auth or self.pool_config.auth, deadline
#     232         )
#     233     except ServiceUnavailable:
#     234         self.deactivate(address)
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\io\_pool.py:637, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     636 def opener(addr, auth_manager, deadline):
# --> 637     return Bolt.open(
#     638         addr,
#     639         auth_manager=auth_manager,
#     640         deadline=deadline,
#     641         routing_context=None,
#     642         pool_config=pool_config,
#     643     )
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\io\_bolt.py:368, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     365 if deadline is None:
#     366     deadline = Deadline(None)
# --> 368 s, protocol_version, handshake, data = BoltSocket.connect(
#     369     address,
#     370     tcp_timeout=pool_config.connection_timeout,
#     371     deadline=deadline,
#     372     custom_resolver=pool_config.resolver,
#     373     ssl_context=pool_config.get_ssl_context(),
#     374     keep_alive=pool_config.keep_alive,
#     375 )
#     377 pool_config.protocol_version = protocol_version
#     378 protocol_handlers = Bolt.protocol_handlers
#
# File d:\miniconda3\envs\phobert_env\Lib\site-packages\neo4j\_sync\io\_bolt_socket.py:376, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     374 else:
#     375     error_strs = "\n".join(map(str, errors))
# --> 376     raise ServiceUnavailable(
#     377         f"Couldn't connect to {address} (resolved to {address_strs}):"
#     378         f"\n{error_strs}"
#     379     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to 52.207.236.148:7687 (resolved to ('52.207.236.148:7687',)):
# Timed out trying to establish connection to ResolvedIPv4Address(('52.207.236.148', 7687))
